# %% [markdown]
# # TTS v5 - Local Version (Kokoro v1.0)
# - Adapted for running locally with Kokoro TTS v1.0
# - Features 54 voices across 8 languages
# - Includes sentence tracking and timeline manifest generation
# - Released January 2025

# %% [markdown]
# ## 0) Environment Setup (Optional)
#
# **This step helps you manage Python packages and avoid conflicts with your system installation.**
#
# - If you have **conda** installed, you can create a fresh environment for this notebook
# - Or use an existing environment by providing its name
# - At the end of the notebook, you can easily clean up and delete the environment to free storage

# %%
import subprocess
import sys
import os

# Flag to track if we created an environment in this notebook
environment_created_by_notebook = False
environment_name = None

# Check if conda is installed
try:
    result = subprocess.run(['conda', '--version'], capture_output=True, text=True, check=True)
    conda_available = True
    print(f"✓ Conda detected: {result.stdout.strip()}")
except (subprocess.CalledProcessError, FileNotFoundError):
    conda_available = False
    print("✗ Conda not found - skipping environment management")
    print("Packages will be installed in your current Python environment")

if conda_available:
    print("\n" + "="*60)
    print("ENVIRONMENT SETUP OPTIONS")
    print("="*60)
    
    choice = input("\nDo you want to:\n  [1] Create a NEW conda environment (recommended)\n  [2] Use an EXISTING environment\n  [3] Skip and use current environment\n\nEnter choice (1/2/3): ").strip()
    
    if choice == "1":
        # Create new environment
        env_name = input("\nEnter name for new environment (default: kokoro_tts): ").strip()
        if not env_name:
            env_name = "kokoro_tts"
        
        print(f"\n→ Creating conda environment: {env_name}")
        print("  This may take a few minutes...")
        
        try:
            # Create environment with Python 3.10
            subprocess.run(['conda', 'create', '-n', env_name, 'python=3.10', '-y'], 
                          check=True, capture_output=True)
            
            environment_created_by_notebook = True
            environment_name = env_name
            
            print(f"✓ Environment '{env_name}' created successfully!")
            print(f"\n{'='*60}")
            print("IMPORTANT: Restart your Jupyter kernel and select the new environment:")
            print(f"  Kernel → Change Kernel → {env_name}")
            print(f"{'='*60}\n")
            
        except subprocess.CalledProcessError as e:
            print(f"✗ Failed to create environment: {e}")
            print("Continuing with current environment...")
    
    elif choice == "2":
        # Use existing environment
        env_name = input("\nEnter name of existing environment: ").strip()
        if env_name:
            environment_name = env_name
            print(f"\n✓ Using existing environment: {env_name}")
            print(f"\n{'='*60}")
            print("IMPORTANT: Make sure your kernel is using this environment:")
            print(f"  Kernel → Change Kernel → {env_name}")
            print(f"{'='*60}\n")
        else:
            print("✗ No environment name provided - using current environment")
    
    else:
        print("\n✓ Using current environment")

print("\nYou can now proceed with the rest of the notebook.")
# Out:
# ✓ Conda detected: conda 25.7.0
#
# ============================================================
# ENVIRONMENT SETUP OPTIONS
# ============================================================
#
# ✓ Using current environment
#
# You can now proceed with the rest of the notebook.

# %% [markdown]
# ## 1) Install Dependencies

# %%
# Core TTS + I/O deps
# !pip install "kokoro>=1.0" soundfile misaki[en] pypdf ebooklib pydub

# Advanced PDF extraction
# !pip install "unstructured[local-inference]"
# !pip install "detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2"

# Note: ffmpeg should be installed on your system for MP3 encoding
# Linux: sudo apt-get install ffmpeg
# macOS: brew install ffmpeg
# Windows: Download from https://ffmpeg.org/

# Silence overly chatty logs
import logging
logging.getLogger("phonemizer").setLevel(logging.ERROR)
logging.getLogger("unstructured").setLevel(logging.ERROR)
logging.getLogger("pypdf").setLevel(logging.CRITICAL)
# Out:
# zsh:1: no matches found: misaki[en]
# Requirement already satisfied: unstructured[local-inference] in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (0.18.15)
# Requirement already satisfied: charset-normalizer in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (3.4.4)
# Requirement already satisfied: filetype in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: python-magic in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (0.4.27)
# Requirement already satisfied: lxml in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (6.0.2)
# Requirement already satisfied: nltk in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (3.9.2)
# Requirement already satisfied: requests in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (4.13.5)
# Requirement already satisfied: emoji in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (2.15.0)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (0.6.7)
# Requirement already satisfied: python-iso639 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (2025.2.18)
# Requirement already satisfied: langdetect in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.0.9)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (2.2.6)
# Requirement already satisfied: rapidfuzz in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (3.14.3)
# Requirement already satisfied: backoff in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (2.2.1)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (4.15.0)
# Requirement already satisfied: unstructured-client in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (0.42.3)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (2.0.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (4.67.1)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (7.0.0)
# Requirement already satisfied: python-oxmsg in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (0.0.2)
# Requirement already satisfied: html5lib in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.1)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (3.5)
# Requirement already satisfied: pypandoc in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.15)
# Requirement already satisfied: effdet in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (0.4.1)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (0.3.15)
# Requirement already satisfied: xlrd in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (2.0.2)
# Requirement already satisfied: markdown in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (3.10)
# Requirement already satisfied: msoffcrypto-tool in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (5.4.2)
# Requirement already satisfied: python-pptx>=1.0.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.0.2)
# Requirement already satisfied: pi-heif in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.1.1)
# Requirement already satisfied: pdf2image in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.17.0)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (2.3.3)
# Requirement already satisfied: pypdf in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (6.1.3)
# Requirement already satisfied: google-cloud-vision in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (3.11.0)
# Requirement already satisfied: onnx>=1.17.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.19.1)
# Requirement already satisfied: python-docx>=1.1.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: unstructured-inference>=1.0.5 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.1.1)
# Requirement already satisfied: pdfminer.six in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (20250506)
# Requirement already satisfied: openpyxl in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (3.1.5)
# Requirement already satisfied: pikepdf in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (10.0.0)
# Requirement already satisfied: onnxruntime>=1.19.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured[local-inference]) (1.23.2)
# Requirement already satisfied: protobuf>=4.25.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from onnx>=1.17.0->unstructured[local-inference]) (6.33.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from onnx>=1.17.0->unstructured[local-inference]) (0.5.3)
# Requirement already satisfied: coloredlogs in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from onnxruntime>=1.19.0->unstructured[local-inference]) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from onnxruntime>=1.19.0->unstructured[local-inference]) (25.9.23)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from onnxruntime>=1.19.0->unstructured[local-inference]) (25.0)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from onnxruntime>=1.19.0->unstructured[local-inference]) (1.13.1)
# Requirement already satisfied: Pillow>=3.3.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from python-pptx>=1.0.1->unstructured[local-inference]) (11.3.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from python-pptx>=1.0.1->unstructured[local-inference]) (3.2.9)
# Requirement already satisfied: python-multipart in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (0.0.20)
# Requirement already satisfied: huggingface-hub in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (0.36.0)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (4.12.0.88)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (3.10.6)
# Requirement already satisfied: torch in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (2.5.1)
# Requirement already satisfied: timm in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (1.0.22)
# Requirement already satisfied: transformers>=4.25.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (4.57.1)
# Requirement already satisfied: accelerate in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (1.11.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (1.16.3)
# Requirement already satisfied: pypdfium2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-inference>=1.0.5->unstructured[local-inference]) (5.0.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[local-inference]) (3.17.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[local-inference]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[local-inference]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[local-inference]) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[local-inference]) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from huggingface-hub->unstructured-inference>=1.0.5->unstructured[local-inference]) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from huggingface-hub->unstructured-inference>=1.0.5->unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from torch->unstructured-inference>=1.0.5->unstructured[local-inference]) (80.9.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from torch->unstructured-inference>=1.0.5->unstructured[local-inference]) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from sympy->onnxruntime>=1.19.0->unstructured[local-inference]) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from beautifulsoup4->unstructured[local-inference]) (2.5)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.19.0->unstructured[local-inference]) (10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from dataclasses-json->unstructured[local-inference]) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from dataclasses-json->unstructured[local-inference]) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[local-inference]) (1.1.0)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from effdet->unstructured[local-inference]) (0.20.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from effdet->unstructured[local-inference]) (2.0.10)
# Requirement already satisfied: omegaconf>=2.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from effdet->unstructured[local-inference]) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from omegaconf>=2.0->effdet->unstructured[local-inference]) (4.9.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[local-inference]) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-cloud-vision->unstructured[local-inference]) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-cloud-vision->unstructured[local-inference]) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-cloud-vision->unstructured[local-inference]) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[local-inference]) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[local-inference]) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference]) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference]) (4.9.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from requests->unstructured[local-inference]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from requests->unstructured[local-inference]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from requests->unstructured[local-inference]) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference]) (0.6.1)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from html5lib->unstructured[local-inference]) (1.17.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from html5lib->unstructured[local-inference]) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from jinja2->torch->unstructured-inference>=1.0.5->unstructured[local-inference]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[local-inference]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[local-inference]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[local-inference]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[local-inference]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[local-inference]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[local-inference]) (2.9.0.post0)
# Requirement already satisfied: cryptography>=39.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from msoffcrypto-tool->unstructured[local-inference]) (46.0.3)
# Requirement already satisfied: olefile>=0.46 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from msoffcrypto-tool->unstructured[local-inference]) (0.47)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from cryptography>=39.0->msoffcrypto-tool->unstructured[local-inference]) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=39.0->msoffcrypto-tool->unstructured[local-inference]) (2.23)
# Requirement already satisfied: click in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from nltk->unstructured[local-inference]) (8.3.0)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from nltk->unstructured[local-inference]) (1.5.2)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from openpyxl->unstructured[local-inference]) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from pandas->unstructured[local-inference]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from pandas->unstructured[local-inference]) (2025.2)
# Requirement already satisfied: Deprecated in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from pikepdf->unstructured[local-inference]) (1.3.1)
# Requirement already satisfied: aiofiles>=24.1.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-client->unstructured[local-inference]) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-client->unstructured[local-inference]) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-client->unstructured[local-inference]) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-client->unstructured[local-inference]) (2.12.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from unstructured-client->unstructured[local-inference]) (1.0.0)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from httpcore>=1.0.9->unstructured-client->unstructured[local-inference]) (0.16.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client->unstructured[local-inference]) (4.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[local-inference]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[local-inference]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[local-inference]) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[local-inference]) (1.3.0)
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2
#   Cloning https://github.com/facebookresearch/detectron2.git (to revision v0.6) to /private/var/folders/4t/cg7byznj6zz9d4cdtnn5rvy40000gn/T/pip-install-doef3e7w/detectron2_80b2a62340b9474b8b1199a4d59e7e91
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /private/var/folders/4t/cg7byznj6zz9d4cdtnn5rvy40000gn/T/pip-install-doef3e7w/detectron2_80b2a62340b9474b8b1199a4d59e7e91
#   Running command git checkout -q d1e04565d3bec8719335b88be9e9b961bf3ec464
#   Resolved https://github.com/facebookresearch/detectron2.git to commit d1e04565d3bec8719335b88be9e9b961bf3ec464
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (11.3.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.10.6)
# Requirement already satisfied: pycocotools>=2.0.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.0.10)
# Requirement already satisfied: termcolor>=1.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.2.0)
# Requirement already satisfied: yacs>=0.1.8 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.1.8)
# Requirement already satisfied: tabulate in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.9.0)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.1.2)
# Requirement already satisfied: tqdm>4.29.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.67.1)
# Requirement already satisfied: tensorboard in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.20.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.1.9)
# Requirement already satisfied: future in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.0.0)
# Requirement already satisfied: pydot in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.0.1)
# Requirement already satisfied: omegaconf>=2.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.3.2)
# Requirement already satisfied: black==21.4b2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (21.4b2)
# Requirement already satisfied: click>=7.1.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (8.3.0)
# Requirement already satisfied: appdirs in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.4.4)
# Requirement already satisfied: toml>=0.10.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.10.2)
# Requirement already satisfied: regex>=2020.1.8 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2025.11.3)
# Requirement already satisfied: pathspec<1,>=0.8.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.12.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.2.6)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (6.0.2)
# Requirement already satisfied: portalocker in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from iopath<0.1.10,>=0.1.7->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from hydra-core>=1.1->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.9.3)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from hydra-core>=1.1->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.17.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (6.33.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (80.9.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.1.3)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from grpcio>=1.48.2->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/tts/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.0.2)

# %% [markdown]
# ## 2) Configuration and Setup

# %%
import os
from pathlib import Path

# --- Output directory setup ---
OUTPUT_DIR = Path(".")  # Use current directory (same as notebook location)
print(f"Output directory: {OUTPUT_DIR.resolve()}")

# --- Device selection ---
# DEVICE_MODE: "auto" (default), "cuda", or "cpu"
DEVICE_MODE = "auto"

import torch
def _pick_device():
    if DEVICE_MODE == "cuda":
        return "cuda"
    if DEVICE_MODE == "cpu":
        return "cpu"
    return "cuda" if torch.cuda.is_available() else "cpu"

DEVICE = _pick_device()
print(f"Using device: {DEVICE}")
# Out:
# Output directory: /Users/simon/Documents/GitHub/ttsweb.github.io
# Using device: cpu

# %% [markdown]
# ## 3) Helper Functions (PDF/EPUB extraction & TTS synthesis)

# %%
import numpy as np
import soundfile as sf
import re, io, zipfile, torch
from pathlib import Path
from typing import List, Tuple, Dict, Union
from functools import lru_cache

from pypdf import PdfReader
from ebooklib import epub
from kokoro import KPipeline
from pydub import AudioSegment

# Imports for advanced PDF extraction
from unstructured.partition.auto import partition

# Sentence-ish split; keeps chunks small (avoids 510-phoneme truncation)
SPLIT_PATTERN = r"[.?!]\s+|[\n]{2,}"
SPLIT_PATTERN_CAP = r"([.?!]\s+|[\n]{2,})"


# --- PDF Extraction using unstructured.io ---
def extract_text_from_pdf(file_like: io.BytesIO) -> List[Dict]:
    """Extract text from PDF using unstructured.io with layout analysis."""
    print("Parsing PDF with layout analysis (strategy='hi_res')...")
    try:
        partitioned_elements = partition(file=file_like, strategy="hi_res", content_type="application/pdf", include_page_breaks=True)
        print(f"Unstructured 'hi_res' returned {len(partitioned_elements)} raw elements.")
    except Exception as e:
        print(f"Unstructured 'hi_res' strategy failed: {e}. Falling back to 'fast'.")
        try:
            file_like.seek(0)
            partitioned_elements = partition(file=file_like, strategy="fast", content_type="application/pdf", include_page_breaks=True)
            print(f"Unstructured 'fast' returned {len(partitioned_elements)} raw elements.")
        except Exception as e2:
            print(f"Unstructured 'fast' strategy also failed: {e2}.")
            return [{"text": "Error: Unstructured parsing failed.", "metadata": {"page_number": 1, "points": None}}]

    element_list = []
    current_page = 1
    print("\n--- Processing elements (checking for points) ---")

    for i, el in enumerate(partitioned_elements):
        meta_dict = el.metadata.to_dict()

        page_num_meta = meta_dict.get("page_number")
        if page_num_meta is not None:
             current_page = page_num_meta

        # Extract coordinate points if available
        points = None
        coords_meta = meta_dict.get("coordinates")
        if coords_meta:
            points = coords_meta.get("points")

        location_data = {
            "page_number": current_page,
            "points": points
        }

        element_text = str(el).strip()
        if element_text:
            element_list.append({
                "text": element_text,
                "metadata": location_data
            })

    print("--- Finished processing elements ---")
    print(f"Unstructured: Found {len(element_list)} text elements.")
    if not element_list:
         return [{"text": "Warning: Unstructured found no text elements.", "metadata": {"page_number": 1, "points": None}}]
    return element_list


# --- EPUB Extraction ---
def extract_chapters_from_epub(file_like: io.BytesIO):
    bk = epub.read_epub(file_like)
    chapters = []
    for item in bk.get_items_of_type(epub.ITEM_DOCUMENT):
        if getattr(item, "is_nav", False): continue
        html = item.get_content().decode("utf-8", errors="ignore")
        text = re.sub(r"<(script|style).*?>.*?</\1>", " ", html, flags=re.S|re.I)
        text = re.sub(r"<br\s*/?>", "\n", text, flags=re.I)
        text = re.sub(r"</p>|</div>|</h\d>", "\n\n", text, flags=re.I)
        text = re.sub(r"<[^>]+>", " ", text)
        text = re.sub(r"[ \t]+", " ", text)
        text = re.sub(r"\n{3,}", "\n\n", text).strip()
        if text:
            title = Path(item.file_name).stem
            first = text.splitlines()[0] if text else ""; m = re.match(r"(?i)\s*(chapter|part|book)\b[^\n]{0,80}", first)
            if m: title = first[:60]
            chapters.append((title, text))
    if not chapters:
        blobs = [];
        for item in bk.get_items_of_type(epub.ITEM_DOCUMENT):
             if getattr(item, "is_nav", False): continue
             blobs.append(item.get_content().decode("utf-8", errors="ignore"))
        html = " ".join(blobs)
        text = re.sub(r"<(script|style).*?>.*?</\1>", " ", html, flags=re.S|re.I)
        text = re.sub(r"<br\s*/?>", "\n", text, flags=re.I)
        text = re.sub(r"</p>|</div>|</h\d>", "\n\n", text, flags=re.I)
        text = re.sub(r"<[^>]+>", " ", text)
        text = re.sub(r"[ \t]+", " ", text)
        text = re.sub(r"\n{3,}", "\n\n", text).strip()
        if text: chapters = [("Chapter 1", text)]
    return chapters

def safe_name(s: str) -> str:
    s = re.sub(r"[^\w\-]+", "_", s).strip("_"); return s or "chapter"

# --- Pipeline cache ---
@lru_cache(maxsize=4)
def get_pipeline(lang_code='a', device=DEVICE):
    return KPipeline(lang_code=lang_code, device=device)

def _synthesize_sentence(pipe: KPipeline, sentence: str, voice='af_heart', speed=1.0) -> np.ndarray:
    subchunks = [];
    for _, _, audio in pipe(sentence, voice=voice, speed=speed, split_pattern=None): subchunks.append(audio)
    if not subchunks: return np.zeros((0,), dtype=np.float32)
    return np.concatenate(subchunks, axis=0)

def split_sentences_keep_delim(text: str) -> List[str]:
    parts = re.split(SPLIT_PATTERN_CAP, text); sents = []
    for i in range(0, len(parts), 2):
        chunk = (parts[i] or "").strip(); sep = parts[i+1] if i+1 < len(parts) else ""
        if not chunk: continue
        if sep and not sep.isspace(): chunk = (chunk + " " + sep.strip()).strip()
        sents.append(chunk)
    return sents

# --- Synthesizer ---
def synth_text_to_wav_and_manifest(
    text_or_elements: Union[str, List[Dict]],
    voice='af_heart',
    speed=1.0,
    lang_code='a',
    device=DEVICE) -> Tuple[bytes, Dict]:
    pipe = get_pipeline(lang_code=lang_code, device=device)
    sr = 24000

    if isinstance(text_or_elements, str):
        elements = [{"text": text_or_elements, "metadata": {"page_number": 1, "points": None}}]
    else:
        elements = text_or_elements

    pcm_all = []; timeline = []; t = 0.0; sentence_index = 0
    print(f"Synthesizing {len(elements)} text elements...")

    for element in elements:
        element_text = element.get("text", "")
        element_meta = element.get("metadata", {})

        sentences = split_sentences_keep_delim(element_text)

        for sent in sentences:
            if not sent: continue
            pcm = _synthesize_sentence(pipe, sent, voice=voice, speed=speed)
            dur = pcm.shape[0] / sr
            timeline.append({
                "i": sentence_index,
                "start": round(t, 3),
                "end": round(t + dur, 3),
                "text": sent.strip(),
                "location": element_meta
            })
            pcm_all.append(pcm); t += dur; sentence_index += 1

    pcm_cat = np.concatenate(pcm_all, axis=0) if pcm_all else np.zeros((sr//10,), dtype=np.float32)
    buf = io.BytesIO(); sf.write(buf, pcm_cat, sr, format='WAV'); buf.seek(0)
    manifest = {"audioUrl": "", "sentences": timeline}
    return buf.read(), manifest

def wav_to_mp3_bytes(wav_bytes: bytes, bitrate="128k") -> bytes:
    audio = AudioSegment.from_file(io.BytesIO(wav_bytes), format="wav"); out = io.BytesIO()
    audio.export(out, format="mp3", bitrate=bitrate); out.seek(0); return out.read()

# %% [markdown]
# ## 4) High-Level Synthesis Wrappers

# %%
def synth_string(text: str,
                 voice="af_heart",
                 speed=1.0,
                 out_format="wav",
                 lang_code="a",
                 device=None,
                 basename="kokoro_text",
                 output_dir=None):
    device = device or DEVICE
    output_dir = Path(output_dir) if output_dir else OUTPUT_DIR

    elements = [{
        "text": text,
        "metadata": {"page_number": 1, "source": "string", "coordinates": None}
    }]

    wav_bytes, manifest = synth_text_to_wav_and_manifest(
        elements,
        voice=voice, speed=speed, lang_code=lang_code, device=device
    )

    out_base = output_dir / basename

    if out_format.lower() == "mp3":
        mp3 = wav_to_mp3_bytes(wav_bytes)
        audio_path = str(out_base) + ".mp3"
        with open(audio_path, "wb") as f: f.write(mp3)
    else:
        audio_path = str(out_base) + ".wav"
        with open(audio_path, "wb") as f: f.write(wav_bytes)

    manifest_path = str(out_base) + "_manifest.json"
    manifest["audioUrl"] = Path(audio_path).name
    with open(manifest_path, "w", encoding="utf-8") as f:
        import json; json.dump(manifest, f, ensure_ascii=False, indent=2)

    return audio_path, manifest_path

def synth_pdf(file_path_or_bytes,
              voice="af_heart",
              speed=1.0,
              out_format="wav",
              lang_code="a",
              device=None,
              basename=None,
              output_dir=None):
    device = device or DEVICE
    output_dir = Path(output_dir) if output_dir else OUTPUT_DIR
    
    if isinstance(file_path_or_bytes, (str, Path)):
        with open(file_path_or_bytes, "rb") as fh:
            pdf_bytes = io.BytesIO(fh.read())
        stem = Path(file_path_or_bytes).stem
    else:
        pdf_bytes = file_path_or_bytes
        stem = basename or "document"

    elements = extract_text_from_pdf(pdf_bytes)

    wav_bytes, manifest = synth_text_to_wav_and_manifest(
        elements,
        voice=voice, speed=speed, lang_code=lang_code, device=device
    )

    out_base = output_dir / f"{(basename or stem)}_tts"

    if out_format.lower() == "mp3":
        mp3 = wav_to_mp3_bytes(wav_bytes)
        audio_path = str(out_base) + ".mp3"
        with open(audio_path, "wb") as f: f.write(mp3)
    else:
        audio_path = str(out_base) + ".wav"
        with open(audio_path, "wb") as f: f.write(wav_bytes)

    manifest_path = str(out_base) + "_manifest.json"
    manifest["audioUrl"] = Path(audio_path).name
    with open(manifest_path, "w", encoding="utf-8") as f:
        import json; json.dump(manifest, f, ensure_ascii=False, indent=2)

    return audio_path, manifest_path

def synth_epub(file_path_or_bytes,
               voice="af_heart",
               speed=1.0,
               per_chapter_format="wav",
               lang_code="a",
               device=None,
               zip_name=None,
               output_dir=None):
    device = device or DEVICE
    output_dir = Path(output_dir) if output_dir else OUTPUT_DIR

    if isinstance(file_path_or_bytes, (str, Path)):
        with open(file_path_or_bytes, "rb") as fh:
            epub_bytes = io.BytesIO(fh.read())
        stem = Path(file_path_or_bytes).stem
    else:
        epub_bytes = file_path_or_bytes
        stem = "book"

    chapters = extract_chapters_from_epub(epub_bytes)
    assert chapters, "No chapters detected in EPUB."

    zip_buf = io.BytesIO()
    with zipfile.ZipFile(zip_buf, "w", zipfile.ZIP_DEFLATED) as zf:
        for idx, (title, body) in enumerate(chapters, 1):
            name = f"{idx:02d}_{safe_name(title)[:40]}"

            chapter_elements = [{
                "text": body,
                "metadata": {
                    "chapter_index": idx,
                    "chapter_title": title,
                    "page_number": 1,
                    "coordinates": None
                }
            }]

            wav_bytes, manifest = synth_text_to_wav_and_manifest(
                chapter_elements,
                voice=voice, speed=speed, lang_code=lang_code, device=device
            )

            if per_chapter_format.lower() == "mp3":
                data = wav_to_mp3_bytes(wav_bytes)
                audio_name = f"{name}.mp3"
                zf.writestr(audio_name, data)
            else:
                audio_name = f"{name}.wav"
                zf.writestr(audio_name, wav_bytes)

            manifest["audioUrl"] = audio_name
            import json
            zf.writestr(f"{name}_manifest.json", json.dumps(manifest, ensure_ascii=False, indent=2))

    zip_buf.seek(0)
    zpath = str(output_dir / f"{zip_name or (stem + '_chapters')}.zip")
    with open(zpath, "wb") as f:
        f.write(zip_buf.read())
    return zpath

# %% [markdown]
# ## Usage Examples
#
# Below are examples for synthesizing text, PDFs, and EPUBs locally.

# %% [markdown]
# ### A) String → Audio

# %%
# Configuration
VOICE = "af_heart"
SPEED = 1.0
FORMAT = "mp3"  # "wav" or "mp3"
LANG = "a"
BASENAME = "kokoro_text"

# Text to synthesize
TEXT = """Paste or type your text here.
It can be multiple paragraphs. Chapters aren't needed for this path.
"""

# Run synthesis
audio_path, manifest_path = synth_string(
    TEXT, 
    voice=VOICE, 
    speed=SPEED,
    out_format=FORMAT, 
    lang_code=LANG,
    basename=BASENAME
)

print(f"Audio saved to: {audio_path}")
print(f"Manifest saved to: {manifest_path}")

# %% [markdown]
# ### B) PDF → Audio (with manifest)

# %%
# Configuration
VOICE = "af_heart"
SPEED = 1.0
FORMAT = "mp3"  # "wav" or "mp3"
LANG = "a"

# Specify the path to your PDF file (relative to notebook location)
PDF_PATH = "Case1Writeup.pdf"  # Change this to your PDF filename

# Run synthesis
audio_path, manifest_path = synth_pdf(
    PDF_PATH, 
    voice=VOICE, 
    speed=SPEED,
    out_format=FORMAT, 
    lang_code=LANG
)

print(f"Audio saved to: {audio_path}")
print(f"Manifest saved to: {manifest_path}")
# Out:
# Parsing PDF with layout analysis (strategy='hi_res')...
# Warning: No languages specified, defaulting to English.
# yolox_l0.05.onnx:   0%|          | 0.00/217M [00:00<?, ?B/s]
# Unstructured 'hi_res' strategy failed: Unable to get page count. Is poppler installed and in PATH?. Falling back to 'fast'.
# Warning: No languages specified, defaulting to English.
# Unstructured 'fast' returned 16 raw elements.
#
# --- Processing elements (checking for points) ---
# --- Finished processing elements ---
# Unstructured: Found 14 text elements.
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# config.json: 0.00B [00:00, ?B/s]
# /opt/anaconda3/envs/tts/lib/python3.12/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(
# /opt/anaconda3/envs/tts/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# kokoro-v1_0.pth:   0%|          | 0.00/327M [00:00<?, ?B/s]
# Synthesizing 14 text elements...
# voices/af_heart.pt:   0%|          | 0.00/523k [00:00<?, ?B/s]
# Audio saved to: Case1Writeup_tts.mp3
# Manifest saved to: Case1Writeup_tts_manifest.json

# %% [markdown]
# ### C) EPUB → ZIP (Per-Chapter Audio + Manifests)

# %%
# Configuration
VOICE = "af_heart"
SPEED = 1.0
CHAPTER_FORMAT = "wav"  # "wav" or "mp3"
LANG = "a"
ZIP_NAME = ""  # Optional: custom name for the output ZIP file

# Specify the path to your EPUB file (relative to notebook location)
EPUB_PATH = "book.epub"  # Change this to your EPUB filename

# Run synthesis
zip_path = synth_epub(
    EPUB_PATH, 
    voice=VOICE, 
    speed=SPEED,
    per_chapter_format=CHAPTER_FORMAT,
    lang_code=LANG,
    zip_name=(ZIP_NAME or None)
)

print(f"ZIP archive saved to: {zip_path}")

# %% [markdown]
# ## Notes
#
# - **Output Directory**: By default, all outputs are saved to the same directory as the notebook. You can change this by modifying `OUTPUT_DIR` in the Configuration cell.
# - **Input Files**: Place your PDF/EPUB files in the same directory as the notebook, or provide relative/absolute paths.
# - **Device Selection**: The notebook will automatically use CUDA if available, otherwise CPU. You can override this by setting `DEVICE_MODE` in the Configuration cell.
# - **Voice Options**: Kokoro v1.0 includes 54 voices across 8 languages:
#   - **US Female**: af_alloy, af_aoede, af_bella, af_heart, af_jessica, af_kore, af_nicole, af_nova, af_river, af_sarah, af_sky
#   - **US Male**: am_adam, am_echo, am_eric, am_fenrir, am_liam, am_michael, am_onyx, am_puck
#   - **British Female**: bf_alice, bf_emma, bf_isabella, bf_lily
#   - **British Male**: bm_daniel, bm_fable, bm_george, bm_lewis
#   - **Additional languages**: French, Japanese, Korean, Chinese (and more)
#   - **Voice Blending**: You can blend voice embeddings to create personalized voices
# - **PDF Extraction**: The notebook uses `unstructured.io` for advanced PDF extraction with layout analysis. This may take longer but provides better results.
# - **Manifest Files**: Each audio output includes a JSON manifest file with sentence-level timing information and metadata.

# %% [markdown]
# ## Cleanup: Delete Environment (Optional)
#
# **If you created a new environment at the beginning of this notebook**, you can delete it here to free up storage space.
#
# ⚠️ **Warning**: This will permanently delete the environment and all installed packages!

# %%
import subprocess

# Check if we created an environment in this notebook
if 'environment_created_by_notebook' not in globals():
    print("✗ No environment tracking found")
    print("This cell only works if you ran the environment setup cell at the beginning")
elif not environment_created_by_notebook:
    print("✗ No environment was created by this notebook")
    print("You can only delete environments that were created in this session")
else:
    print(f"Environment '{environment_name}' was created by this notebook")
    print(f"\n{'='*60}")
    print("DELETE ENVIRONMENT")
    print(f"{'='*60}")
    
    confirm = input(f"\nAre you sure you want to DELETE '{environment_name}'?\nType 'yes' to confirm: ").strip().lower()
    
    if confirm == 'yes':
        print(f"\n→ Deleting environment '{environment_name}'...")
        print("  This may take a moment...")
        
        try:
            subprocess.run(['conda', 'env', 'remove', '-n', environment_name, '-y'], 
                          check=True, capture_output=True)
            print(f"✓ Environment '{environment_name}' deleted successfully!")
            print("  Storage space has been freed.")
            
            # Reset the flag
            environment_created_by_notebook = False
            environment_name = None
            
        except subprocess.CalledProcessError as e:
            print(f"✗ Failed to delete environment: {e}")
            print("You may need to delete it manually with: conda env remove -n {environment_name}")
    else:
        print("\n✗ Deletion cancelled - environment preserved")
